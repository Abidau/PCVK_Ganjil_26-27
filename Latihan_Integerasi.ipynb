# %% [markdown]
# <a href="https://colab.research.google.com/github/Abidau/PCVK_Ganjil_26-27/blob/main/Latihan_Integerasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah (Step 1)

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Langkah (Step) 2

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekittens.com/g/800/571"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Langkah (Step) 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# Langkah (Step) 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2

# %% [markdown]
# 1. karena memudahkan menjalankan kode python tidak perlu instalasi package yang dibutuhkan oleh python tersebut, pada google codelab bisa langsung menjalankan kode python yang sudah dirancang
#
# 2. penjelasannya sebagai berikut
#   - NumPy berfungsi untuk mengelolah array atau matriks yang termasuk data pixel pada gambar
#
#   - Pandas berfungsi mengolah dan menganalisis data dalam bentul tabel atau dataframe
#
# - OpenCV berfungsi pengolahan citra atau gambar, seperti membaca, mengubah warna, dan manipulasi gambar
#
# - cv2_imshow berfungsi untuk Menampilkan gambar di Google Colab
#
# - Scikit-image(io) berfungsi membaca dan menulis gambar
#
# - Scikit-image(transform) berfungsi melakukan transformasi gambar, seperti resize, rotate, dan warp
#
# - PIL berfungsi sebagai membuka, mengedit, dan menyimpan gambar
#
# - Matpotlib berfungsi menampilkan dan memvisualisasikan gambar atau data dalam bentuk grafik
#
# Semua tidak harus digunakan karena library yang digunakan bergantung pada kebutuhan praktikum. Jika praktikum hanya melakukan manipulasi gambar menggunakan OpenCV dan NumPy, maka tidak semua library diatas harus digunakan. Library yang tidak diperlukan cukup tidak dipanggil atua digunakan.
#
# 3. kode tersebut digunakan untuk mengubah ukuran gambar dari nilai fx=0.5 dan fy-0.5 jadi ukuran gambar diperkecil menjadi 50% dari ukuran semula, baik lebar atau tingginya
#
# 4. kegunaan pada kode tersebut digunakan untuk menjadikan sebuah pixel menjadi warna putih karena 255 tersebut adalah berwarna putih
#
# 5.pixel adalah titik kecil yang menyusun sebuah gambar, jika resolusi menunjukkan jumlah pixel yang dimiliki gambar. Jadi, semakin banyak pixel yang digunakan untuk mempresentasikan suatu gambar, semakin tinggi resolusinya dan semakin banyak detail yang dapat ditampilkan

# %% [markdown]
# TUGAS PRAKTIKUM D2

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    y = int(x * (lebar - 1) / (tinggi - 1))
    image_3[x,y] = [255, 255, 255]

for x in range(tinggi):
    y = int((tinggi - 1 - x) * (lebar - 1) / (tinggi - 1))
    image_3[x,y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    image_3[int((tinggi)/2), 75:150] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

x = 75
y = 50
ukuran = 100

image_3[y:y+ukuran, x:x+ukuran] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
